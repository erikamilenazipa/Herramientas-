# %%
import pandas as pd

# %%
df = pd.read_csv('Eventos_de_inter_s_en_salud_p_blica_registrados_en_el_Municipio_de_Acac_as_20250418.csv')

# %%
df.shape
# Out:
# (21820, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21820 entries, 0 to 21819
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre del Evento         21820 non-null  object
#  1   Edad                      21820 non-null  int64
#  2   Unidad_medida             21820 non-null  object
#  3   Sexo                      21820 non-null  object
#  4   Area                      21816 non-null  object
#  5   Tipo de Seguridad social  21820 non-null  object
#  6   Año de consulta           21820 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ MB

# %%
df
# Out:
#                                        Nombre del Evento  Edad Unidad_medida  \
# 0                DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     1          AÑOS
# 1                DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     6         MESES
# 2                DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     2          AÑOS
# 3                DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4          AÑOS
# 4                DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4          AÑOS
# ...                                                  ...   ...           ...
# 21815                                             DENGUE     3          AÑOS
# 21816                                     INTOXICACIONES     3          AÑOS
# 21817  VIGILANCIA EN SALUD PÚBLICA DE LA VIOLENCIA DE...     3          AÑOS
# 21818                                             DENGUE     3          AÑOS
# 21819                                VARICELA INDIVIDUAL     6          AÑOS
#
# ...

# %%
df.columns
# Out:
# Index(['Nombre del Evento', 'Edad', 'Unidad_medida', 'Sexo', 'Area',
#        'Tipo de Seguridad social', 'Año de consulta'],
#       dtype='object')

# %%
df.head(20)
# Out:
#                                     Nombre del Evento  Edad Unidad_medida  \
# 0             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     1          AÑOS
# 1             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     6         MESES
# 2             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     2          AÑOS
# 3             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4          AÑOS
# 4             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4          AÑOS
# 5             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     2          AÑOS
# 6             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     2          AÑOS
# 7             DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     7         MESES
# 8                                              DENGUE    58          AÑOS
# 9                                         PAROTIDITIS    25          AÑOS
# 10            DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4         MESES
# 11            DESNUTRICIÓN AGUDA EN MENORES DE 5 AÑOS     4         MESES
# ...

# %%
df.tail(10)
# Out:
#                                        Nombre del Evento  Edad Unidad_medida  \
# 21810                                SIFILIS GESTACIONAL    10          AÑOS
# 21811  AGRESIONES POR ANIMALES POTENCIALMENTE TRANSMI...    23          AÑOS
# 21812                                             DENGUE    26          AÑOS
# 21813  VIGILANCIA EN SALUD PÚBLICA DE LA VIOLENCIA DE...    45          AÑOS
# 21814  VIGILANCIA EN SALUD PÚBLICA DE LA VIOLENCIA DE...     5          AÑOS
# 21815                                             DENGUE     3          AÑOS
# 21816                                     INTOXICACIONES     3          AÑOS
# 21817  VIGILANCIA EN SALUD PÚBLICA DE LA VIOLENCIA DE...     3          AÑOS
# 21818                                             DENGUE     3          AÑOS
# 21819                                VARICELA INDIVIDUAL     6          AÑOS
#
#             Sexo                Area Tipo de Seguridad social Año de consulta
# ...

# %%
df.loc(1)

# %%
df.Edad.describe()
# Out:
# count    21820.000000
# mean        33.070394
# std         19.435561
# min          0.000000
# 25%         19.000000
# 50%         32.000000
# 75%         45.000000
# max        109.000000
# Name: Edad, dtype: float64

# %%
df.Sexo.describe()
# Out:
# count         21820
# unique            4
# top       MASCULINO
# freq          11678
# Name: Sexo, dtype: object

# %%
df.Area.describe()
# Out:
# count      21816
# unique         4
# top       URBANA
# freq       15539
# Name: Area, dtype: object

# %%
df.Unidad_medida.describe()
# Out:
# count     21820
# unique        4
# top        AÑOS
# freq      21445
# Name: Unidad_medida, dtype: object

# %%
df["Sexo"].unique()
# Out:
# array(['FEMENINO', 'MASCULINO', 'I', 'INDETERMINADO'], dtype=object)

# %%
df.Sexo.unique()
# Out:
# array(['FEMENINO', 'MASCULINO', 'I', 'INDETERMINADO'], dtype=object)
