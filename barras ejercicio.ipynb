# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Eventos_de_inter_s_en_salud_p_blica_registrados_en_el_Municipio_de_Acac_as_20250505.csv")

# %%
df.shape
# Out:
# (21820, 7)

# %%
df.groupby('Area')['Tipo de Seguridad social'].sum().reset_index()
# Out:
#                  Area                           Tipo de Seguridad social
# 0  CABECERA MUNICIPAL  SUBSIDIADOCONTRIBUTIVOCONTRIBUTIVOCONTRIBUTIVO...
# 1      CENTRO POBLADO  CONTRIBUTIVOSUBSIDIADOSUBSIDIADOSUBSIDIADOCONT...
# 2      RURAL DISPERSO  SUBSIDIADOCONTRIBUTIVOSUBSIDIADOSUBSIDIADOSUBS...
# 3              URBANA  SUBSIDIADOSUBSIDIADOCONTRIBUTIVOSUBSIDIADOSUBS...

# %%
sns.barplot(data=df, x="Area", y="Tipo de Seguridad social", estimator=sum)
# Out:
# <Axes: xlabel='Area', ylabel='Tipo de Seguridad social'>

# %%
sns.barplot(data=df, x="Sexo", y="Edad", estimator=sum)
# Out:
# <Axes: xlabel='Sexo', ylabel='Edad'>

# %%
sns.barplot(data=df, x="Año de consulta", y="Area", estimator=sum)
# Out:
# <Axes: xlabel='Año de consulta', ylabel='Area'>
